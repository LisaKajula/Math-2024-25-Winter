# %% [markdown]
# <a href="https://colab.research.google.com/github/lisalikestocode/final/blob/main/Notebooks_EN/01_Linear_Algebra/02_Systems_of_Linear_Equations/LA_SoLe_inverse_matrix_en.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Solving Systems of Linear Equations Using the Inverse Matrix Method
#
# Converting a system of linear equations to matrix form allows the use of the inverse matrix to find the solution.
#
# As an example, consider $A \cdot X = B$, where the matrix $A_{n \times n}$ is square and non-singular, and $X$ and $B$ are column matrices:
#
# $$
# X = \begin{bmatrix} x_1 \\ x_2 \\ \vdots \\ x_n \end{bmatrix}, \qquad B = \begin{bmatrix} b_1 \\ b_2 \\ \vdots \\ b_n \end{bmatrix}
# $$
#
# The solution of the system can be found by multiplying the inverse of $A$ by $B$ on the left side:
#
# $$(A^{-1} \cdot A) \cdot X = A^{-1} \cdot B$$
#
# $$1 \cdot X = A^{-1} \cdot B$$
#
# $$X = A^{-1} \cdot B$$
#
# **Example**
#
# Consider the system of equations:
#
# $$
# \begin{cases}
# x + 2z = 3, \\
# 2x + 3y + z = 0, \\
# x + 3z = 1.
# \end{cases}
# $$
#
# First, write the system of equations in matrix form:
#
# $$
# \begin{cases}
# 1 \cdot x + 0 \cdot y + 2 \cdot z = 3, \\
# 2 \cdot x + 3 \cdot y + 1 \cdot z = 0, \\
# 1 \cdot x + 0 \cdot y + 3 \cdot z = 1.
# \end{cases}
# $$
#
# $$
# \begin{bmatrix}
# 1 & 0 & 2 \\
# 2 & 3 & 1 \\
# 1 & 0 & 3
# \end{bmatrix}
# \begin{bmatrix}
# x \\
# y \\
# z
# \end{bmatrix}
# =
# \begin{bmatrix}
# 3 \\
# 0 \\
# 1
# \end{bmatrix}
# $$
#
# Solve the system by multiplying by the inverse matrix (on the correct side!):
#
# $$
# \begin{bmatrix}
# x \\
# y \\
# z
# \end{bmatrix}
# =
# \begin{bmatrix}
# 1 & 0 & 2 \\
# 2 & 3 & 1 \\
# 1 & 0 & 3
# \end{bmatrix}^{-1}
# \begin{bmatrix}
# 3 \\
# 0 \\
# 1
# \end{bmatrix}
# $$
#
# Calculate the inverse matrix:
#
# $$
# \begin{bmatrix}
# 1 & 0 & 2 \\
# 2 & 3 & 1 \\
# 1 & 0 & 3
# \end{bmatrix}^{-1}
# =
# \begin{bmatrix}
#  4 &  0 & -2 \\
# -3 &  1 &  1 \\
# -1 &  0 &  1
# \end{bmatrix}
# $$
#
# Multiply the matrices:
#
# $$
# \begin{bmatrix}
# x \\
# y \\
# z
# \end{bmatrix}
# =
# \begin{bmatrix}
#  4 &  0 & -2 \\
# -3 &  1 &  1 \\
# -1 &  0 &  1
# \end{bmatrix}
# \begin{bmatrix}
# 3 \\
# 0 \\
# 1
# \end{bmatrix}
# =
# \begin{bmatrix}
# 7 \\
# -4 \\
# -2
# \end{bmatrix}
# $$

# %%
# ## Solving Systems of Linear Equations Using the Inverse Matrix Method

import sympy as sp

# Coefficient matrix
A = sp.Matrix([
    [1, 0, 2],
    [2, 3, 1],
    [1, 0, 3]
])

# Constant terms vector
B =  sp.Matrix([
    [3],
    [0],
    [1]
])
# Inverse matrix
A_inv = A.inv()

# Solution of the system of equations
X = A_inv * B
X
# Out:
# Matrix([
# [ 7],
# [-4],
# [-2]])

# %% [markdown]
# ---
#
# ## Exercises for Students
#
# 1. Solve the system of linear equations using the inverse matrix method:
#
# $$
# \begin{cases}
# x + 2y + 3z = 5, \\
# 2y + 3z = 4, \\
# 3z = 3.
# \end{cases}
# $$
#
# 2. Solve the system of linear equations using the inverse matrix method:
#
# $$
# \begin{cases}
# x_1 + 2x_2 + 3x_3 = 41, \\
# 4x_1 + 5x_2 + 6x_3 = 93, \\
# 7x_1 + 8x_2 + 9x_3 = 145.
# \end{cases}
# $$
# #HOMEWORK
#
# ## 1 $$
# \begin{cases}
# x + 2y + 3z = 5, \\
# 2y + 3z = 4, \\
# 3z = 3.
# \end{cases}
# $$
# $$
# \begin{cases}
# 1 \cdot x + 2 \cdot y + 3 \cdot z = 5, \\
# 0 \cdot x + 2 \cdot y + 3 \cdot z = 4, \\
# 0 \cdot x + 0\cdot y + 3 \cdot z = 3.
# \end{cases}
# $$
# ##First, write the system of equations in matrix form:
# $\begin {bmatrix}1&2 &3\\0 &2& 3\\0&0&3\end{bmatrix}$ $\begin {bmatrix}x\\y\\z\end{bmatrix}$=$\begin {bmatrix}5\\4\\3\end{bmatrix}$
# ##Solve the system by multiplying by the inverse matrix (on the correct side!):
#
#  $\begin {bmatrix}x\\y\\z\end{bmatrix}$=
# $\begin {bmatrix}1&2 &3\\0 &2& 3\\0&0&3\end{bmatrix}^{-1}$
#  $\begin {bmatrix}5\\4\\3\end{bmatrix}$
#
# ##Calculate the inverse matrix:
# $\begin {bmatrix}1&2 &3\\0 &2& 3\\0&0&3\end{bmatrix}^{-1}$=
# $\begin {bmatrix}1&-1 &0\\0 &\frac{1}{2}& \frac{-1}{2}\\0&0&\frac{1}{3}\end{bmatrix}$
# ##Multiply the matrices:
#  $\begin {bmatrix}x\\y\\z\end{bmatrix}$=
# $\begin {bmatrix}1&-1 &0\\0 &\frac{1}{2}& \frac{-1}{2}\\0&0&1/3\end{bmatrix}$ *
#  $\begin {bmatrix}5\\4\\3\end{bmatrix}$
# ##this gives us:
#  $\begin {bmatrix}1\\\frac{1}{2}\\1\end{bmatrix}$
#
#
# # 2.
#  $$
# \begin{cases}
# x_1 + 2x_2 + 3x_3 = 41, \\
# 4x_1 + 5x_2 + 6x_3 = 93, \\
# 7x_1 + 8x_2 + 9x_3 = 145.
# \end{cases}
# $$
# ##First, write the system of equations in matrix form:
# $\begin {bmatrix}1&2 &3\\4 &5& 6\\7&8&9\end{bmatrix}$ $\begin {bmatrix}x_1\\x_2\\x_3\end{bmatrix}$=$\begin {bmatrix}41\\93\\145\end{bmatrix}$
# ##Solve the system by multiplying by the inverse matrix (on the correct side!):
# $\begin {bmatrix}x_1\\x_2\\x_3\end{bmatrix}$=$\begin {bmatrix}1&2 &3\\4 &5& 6\\7&8&9\end{bmatrix}^{-1}$
# $\begin {bmatrix}x_1\\x_2\\x_3\end{bmatrix}$
# ##Matrix is singular and does not have an inverse
# Because this matrix is singular (its determinant is 0)

# %%
import sympy as sp

# System 1: x + 2y + 3z = 5, 2y + 3z = 4, 3z = 3

# Coefficient matrix for System 1
A1 = sp.Matrix([
    [1, 2, 3],
    [0, 2, 3],
    [0, 0, 3]
])

# Constant terms vector for System 1
B1 = sp.Matrix([
    [5],
    [4],
    [3]
])

# Inverse of matrix A1
A1_inv = A1.inv()

# Solution of the system of equations for System 1
X1 = A1_inv * B1
print(f"Solution for System 1: {X1}")

# System 2: x1 + 2x2 + 3x3 = 41, 4x1 + 5x2 + 6x3 = 93, 7x1 + 8x2 + 9x3 = 145

# Coefficient matrix for System 2
A2 = sp.Matrix([
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
])

# Constant terms vector for System 2
B2 = sp.Matrix([
    [41],
    [93],
    [145]
])

# Inverse of matrix A2
A2_inv = A2.inv()

# Solution of the system of equations for System 2
X2 = A2_inv * B2
print(f"Solution for System 2: {X2}")
# Out:
# Solution for System 1: Matrix([[1], [1/2], [1]])
# ---------------------------------------------------------------------------
# DMNonInvertibleMatrixError                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/sympy/matrices/inverse.py in _inv_DM(dM, cancel)
#     325     try:
# --> 326         dMi, den = dM.inv_den()
#     327     except DMNonInvertibleMatrixError:
#
# /usr/local/lib/python3.10/dist-packages/sympy/polys/matrices/domainmatrix.py in inv_den(self, method)
#    2742         I = self.eye(self.shape, self.domain)
# -> 2743         return self.solve_den(I, method=method)
#    2744
#
# /usr/local/lib/python3.10/dist-packages/sympy/polys/matrices/domainmatrix.py in solve_den(self, b, method)
#    2882         elif method == 'rref':
# -> 2883             xnum, xden = self.solve_den_rref(b)
#    2884         else:
#
# /usr/local/lib/python3.10/dist-packages/sympy/polys/matrices/domainmatrix.py in solve_den_rref(self, b)
#    2934         if len(pivots) != n or pivots and pivots[-1] >= n:
# -> 2935             raise DMNonInvertibleMatrixError("Non-unique solution.")
#    2936
#
# DMNonInvertibleMatrixError: Non-unique solution.
#
# During handling of the above exception, another exception occurred:
#
# NonInvertibleMatrixError                  Traceback (most recent call last)
# <ipython-input-1-fb2d4baa1d89> in <cell line: 43>()
#      41
#      42 # Inverse of matrix A2
# ---> 43 A2_inv = A2.inv()
#      44
#      45 # Solution of the system of equations for System 2
#
# /usr/local/lib/python3.10/dist-packages/sympy/matrices/matrixbase.py in inv(self, method, iszerofunc, try_block_diag)
#    5217
#    5218     def inv(self, method=None, iszerofunc=_iszero, try_block_diag=False):
# -> 5219         return _inv(self, method=method, iszerofunc=iszerofunc,
#    5220                 try_block_diag=try_block_diag)
#    5221
#
# /usr/local/lib/python3.10/dist-packages/sympy/matrices/inverse.py in _inv(M, method, iszerofunc, try_block_diag)
#     502
#     503     if method == "DM":
# --> 504         rv = _inv_DM(dM)
#     505     elif method == "DMNC":
#     506         rv = _inv_DM(dM, cancel=False)
#
# /usr/local/lib/python3.10/dist-packages/sympy/matrices/inverse.py in _inv_DM(dM, cancel)
#     326         dMi, den = dM.inv_den()
#     327     except DMNonInvertibleMatrixError:
# --> 328         raise NonInvertibleMatrixError("Matrix det == 0; not invertible.")
#     329
#     330     if use_exact:
#
# NonInvertibleMatrixError: Matrix det == 0; not invertible.
